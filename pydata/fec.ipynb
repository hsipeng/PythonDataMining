# 1001719  C00500587  P20003281         Perry, Rick              LUCAS, ELISABET  ...     NaN                                                NaN   SA17A   772060
# 1001720  C00500587  P20003281         Perry, Rick               HARDER, ROBERT  ...     NaN                                                NaN   SA17A   772060
# 1001721  C00500587  P20003281         Perry, Rick            HANSEN, STEVE MR.  ...       X                                    SEE ATTRIBUTION   SA17A   772060
# 1001722  C00500587  P20003281         Perry, Rick               HARDER, ROBERT  ...     NaN                                                NaN   SA17A   772060
# 1001723  C00500587  P20003281         Perry, Rick               HARDER, ROBERT  ...     NaN                                                NaN   SA17A   772060
# 1001724  C00500587  P20003281         Perry, Rick  HEFFERNAN, JILL PRINCE MRS.  ...     NaN                                                NaN   SA17A   751678
# 1001725  C00500587  P20003281         Perry, Rick             ELWOOD, MIKE MR.  ...     NaN                                                NaN   SA17A   751678
# 1001726  C00500587  P20003281         Perry, Rick         GORMAN, CHRIS D. MR.  ...     NaN  REATTRIBUTION / REDESIGNATION REQUESTED (AUTOM...   SA17A   751678
# 1001727  C00500587  P20003281         Perry, Rick          DUFFY, DAVID A. MR.  ...     NaN                                                NaN   SA17A   751678
# 1001728  C00500587  P20003281         Perry, Rick          GRANE, BRYAN F. MR.  ...     NaN                                                NaN   SA17A   751678
# 1001729  C00500587  P20003281         Perry, Rick           TOLBERT, DARYL MR.  ...     NaN                                                NaN   SA17A   751678
# 1001730  C00500587  P20003281         Perry, Rick       ANDERSON, MARILEE MRS.  ...     NaN                                                NaN   SA17A   751678
#
# [1001731 rows x 16 columns]

# %%
fec.ix[123456]
# Out:
# /Users/lirawx/.pyenv/versions/anaconda3-5.3.0/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
# cmte_id                             C00431445
# cand_id                             P80003338
# cand_nm                         Obama, Barack
# contbr_nm                         ELLMAN, IRA
# contbr_city                             TEMPE
# contbr_st                                  AZ
# contbr_zip                          852816719
# contbr_employer      ARIZONA STATE UNIVERSITY
# contbr_occupation                   PROFESSOR
# contb_receipt_amt                          50
# contb_receipt_dt                    01-DEC-11
# receipt_desc                              NaN
# memo_cd                                   NaN
# memo_text                                 NaN
# form_tp                                 SA17A
# file_num                               772372
# Name: 123456, dtype: object

# %%
fec.loc[123456]
# Out:
# cmte_id                             C00431445
# cand_id                             P80003338
# cand_nm                         Obama, Barack
# contbr_nm                         ELLMAN, IRA
# contbr_city                             TEMPE
# contbr_st                                  AZ
# contbr_zip                          852816719
# contbr_employer      ARIZONA STATE UNIVERSITY
# contbr_occupation                   PROFESSOR
# contb_receipt_amt                          50
# contb_receipt_dt                    01-DEC-11
# receipt_desc                              NaN
# memo_cd                                   NaN
# memo_text                                 NaN
# form_tp                                 SA17A
# file_num                               772372
# Name: 123456, dtype: object

# %%
unique_cands = fec.cand_nm.unique()
unique_cands
# Out:
# array(['Bachmann, Michelle', 'Romney, Mitt', 'Obama, Barack',
#        "Roemer, Charles E. 'Buddy' III", 'Pawlenty, Timothy',
#        'Johnson, Gary Earl', 'Paul, Ron', 'Santorum, Rick',
#        'Cain, Herman', 'Gingrich, Newt', 'McCotter, Thaddeus G',
#        'Huntsman, Jon', 'Perry, Rick'], dtype=object)

# %%
parties={'Bachmann, Michelle':'Republican','Cain, Herman':'Republican','Gingrich, Newt':'Republican','Huntsman, Jon':'Republican','Johnson, GaryEarl':'Republican','McCotter, ThaddeusG':'Republican','Obama, Barack':'Democrat','Paul, Ron':'Republican','Pawlenty, Timothy':'Republican','Perry, Rick':'Republican',"Roemer, CharlesE. 'Buddy' III":'Republican','Romney, Mitt':'Republican','Santorum, Rick':'Republican'}

fec.cand_nm[123456:123461]
# Out:
# 123456    Obama, Barack
# 123457    Obama, Barack
# 123458    Obama, Barack
# 123459    Obama, Barack
# 123460    Obama, Barack
# Name: cand_nm, dtype: object

# %%
fec.cand_nm[123456:123461].map(parties)
# Out:
# 123456    NaN
# 123457    NaN
# 123458    NaN
# 123459    NaN
# 123460    NaN
# Name: cand_nm, dtype: object

# %%
parties
# Out:
# {'Bachmann,Michelle': 'Republican',
#  'Cain,Herman': 'Republican',
#  'Gingrich,Newt': 'Republican',
#  'Huntsman,Jon': 'Republican',
#  'Johnson,GaryEarl': 'Republican',
#  'McCotter,ThaddeusG': 'Republican',
#  'Obama,Barack': 'Democrat',
#  'Paul,Ron': 'Republican',
#  'Pawlenty,Timothy': 'Republican',
#  'Perry,Rick': 'Republican',
#  "Roemer,CharlesE.'Buddy'III": 'Republican',
#  'Romney,Mitt': 'Republican',
#  'Santorum,Rick': 'Republican'}

# %%
parties={'Bachmann, Michelle':'Republican','Cain, Herman':'Republican','Gingrich, Newt':'Republican','Huntsman, Jon':'Republican','Johnson, GaryEarl':'Republican','McCotter, ThaddeusG':'Republican','Obama, Barack':'Democrat','Paul, Ron':'Republican','Pawlenty, Timothy':'Republican','Perry, Rick':'Republican',"Roemer, CharlesE. 'Buddy' III":'Republican','Romney, Mitt':'Republican','Santorum, Rick':'Republican'}
fec.cand_nm[123456:123461].map(parties)
# Out:
# 123456    Democrat
# 123457    Democrat
# 123458    Democrat
# 123459    Democrat
# 123460    Democrat
# Name: cand_nm, dtype: object

# %%
fec['party'] = fec.cand_nm.map(parties)

fec['party'].value_counts()
# Out:
# Democrat      593746
# Republican    400757
# Name: party, dtype: int64

# %%
(fec.contb_receipt_amt > 0).value_counts()
# Out:
# True     991475
# False     10256
# Name: contb_receipt_amt, dtype: int64

# %%
fec = fec[fec.contb_receipt_amt > 0]

fec_mrbo = fec[fec.cand_nm.isin(['Obama, Barack', 'Romney, Mitt'])]

fec_mrbo
# Out:
#           cmte_id    cand_id        cand_nm                 contbr_nm      contbr_city contbr_st  ... receipt_desc memo_cd                  memo_text  form_tp file_num       party
# 411     C00431171  P80003353   Romney, Mitt        ELDERBAUM, WILLIAM              DPO        AA  ...          NaN     NaN                        NaN    SA17A   780124  Republican
# 412     C00431171  P80003353   Romney, Mitt        ELDERBAUM, WILLIAM              DPO        AA  ...          NaN     NaN                        NaN    SA17A   780124  Republican
# 413     C00431171  P80003353   Romney, Mitt          CARLSEN, RICHARD              APO        AE  ...          NaN     NaN                        NaN    SA17A   785689  Republican
#
AK  ...          NaN     NaN                        NaN    SA17A   785689  Republican
# 440     C00431171  P80003353   Romney, Mitt    MCQUEEN, DENNIS L. MR.        FAIRBANKS        AK  ...          NaN     NaN                        NaN    SA17A   785689  Republican
# ...           ...        ...            ...                       ...              ...       ...  ...          ...     ...                        ...      ...      ...         ...
# 701356  C00431445  P80003338  Obama, Barack            WOODS, WILLIAM         BAR NUNN        WY  ...          NaN     NaN                        NaN    SA17A   780234    Democrat
# 701357  C00431445  P80003338  Obama, Barack             STOVAL, LINDA           CASPER        WY  ...          NaN     NaN                        NaN    SA17A   780234    Democrat
# 701358  C00431445  P80003338  Obama, Barack             HAGEN, MARTIN          JACKSON        WY  ...          NaN     NaN                        NaN    SA17A   780234    Democrat
# 701359  C00431445  P80003338  Obama, Barack              MILLS, DAVID          JACKSON        WY  ...          NaN     NaN                        NaN    SA17A   780234    Democrat
# 701360  C00431445  P80003338  Obama, Barack           PHELPS, WILLIAM          JACKSON        WY  ...          NaN     NaN                        NaN    SA17A   780234    Democrat
# 701361  C00431445  P80003338  Obama, Barack           MARLATT, GORDON          LARAMIE        WY  ...          NaN     NaN                        NaN    SA17A   780234    Democrat
# 701362  C00431445  P80003338  Obama, Barack          GOTTFRIED, BETTE           CASPER        WY  ...          NaN     NaN                        NaN    SA17A   785239    Democrat
# 701363  C00431445  P80003338  Obama, Barack             STOVAL, LINDA           CASPER        WY  ...          NaN     NaN                        NaN    SA17A   785239    Democrat
# 701364  C00431445  P80003338  Obama, Barack            MILES, MATTHEW           ALPINE        WY  ...          NaN     NaN                        NaN    SA17A   785239    Democrat
# 701365  C00431445  P80003338  Obama, Barack           NELSON, JANE B.         CHEYENNE        WY  ...          NaN     NaN                        NaN    SA17A   785239    Democrat
# 701366  C00431445  P80003338  Obama, Barack             HAGEN, MARTIN          JACKSON        WY  ...          NaN     NaN                        NaN    SA17A   785239    Democrat
# 701367  C00431445  P80003338  Obama, Barack           EMORY, DENNIS S           WILSON        WY  ...          NaN     NaN                        NaN    SA17A   785239    Democrat
# 701368  C00431445  P80003338  Obama, Barack             IRWIN, C. DON          DOUGLAS        WY  ...          NaN     NaN                        NaN    SA17A   785239    Democrat
# 701369  C00431445  P80003338  Obama, Barack            LIU, FREDERICK          JACKSON        WY  ...          NaN     NaN                        NaN    SA17A   785239    Democrat
# 701370  C00431445  P80003338  Obama, Barack             KNIGHT, CINDY          JACKSON        WY  ...          NaN     NaN                        NaN    SA17A   785239    Democrat
# 701371  C00431445  P80003338  Obama, Barack               NEAL, AMBER              APO        ZZ  ...          NaN     NaN                        NaN    SA17A   756218    Democrat
# 701372  C00431445  P80003338  Obama, Barack            MOUNTS, ROBERT              APO        ZZ  ...          NaN     NaN                        NaN    SA17A   780234    Democrat
# 701373  C00431445  P80003338  Obama, Barack            MOUNTS, ROBERT              APO        ZZ  ...          NaN     NaN                        NaN    SA17A   772372    Democrat
# 701374  C00431445  P80003338  Obama, Barack            TUCKER, PAMELA              APO        ZZ  ...          NaN     NaN                        NaN    SA17A   772372    Democrat
# 701375  C00431445  P80003338  Obama, Barack            MOUNTS, ROBERT              APO        ZZ  ...          NaN     NaN                        NaN    SA17A   772372    Democrat
# 701376  C00431445  P80003338  Obama, Barack             JONES, LESLIE  HAMILTON PARISH        ZZ  ...          NaN       X  * OBAMA VICTORY FUND 2012     SA18   772372    Democrat
# 701377  C00431445  P80003338  Obama, Barack            MOUNTS, ROBERT              APO        ZZ  ...          NaN     NaN                        NaN    SA17A   772372    Democrat
# 701378  C00431445  P80003338  Obama, Barack            MOUNTS, ROBERT              APO        ZZ  ...          NaN     NaN                        NaN    SA17A   775668    Democrat
# 701379  C00431445  P80003338  Obama, Barack        GOLDSTINE, RAYMOND              APO        ZZ  ...          NaN     NaN                        NaN    SA17A   787803    Democrat
# 701380  C00431445  P80003338  Obama, Barack             JONES, LESLIE  HAMILTON PARISH        ZZ  ...          NaN       X  * OBAMA VICTORY FUND 2012     SA18   772372    Democrat
# 701381  C00431445  P80003338  Obama, Barack            MOUNTS, ROBERT              APO        ZZ  ...          NaN     NaN                        NaN    SA17A   787803    Democrat
# 701382  C00431445  P80003338  Obama, Barack           TAITANO, TYRONE          HAGATNA        ZZ  ...          NaN     NaN                        NaN    SA17A   775668    Democrat
# 701383  C00431445  P80003338  Obama, Barack            TUCKER, PAMELA              APO        ZZ  ...          NaN     NaN                        NaN    SA17A   775668    Democrat
# 701384  C00431445  P80003338  Obama, Barack            MOUNTS, ROBERT              APO        ZZ  ...          NaN     NaN                        NaN    SA17A   785239    Democrat
# 701385  C00431445  P80003338  Obama, Barack               NEAL, AMBER              APO        ZZ  ...          NaN       X  * OBAMA VICTORY FUND 2012     SA18   756218    Democrat
#
# [694282 rows x 17 columns]

# %%
fec.contbr_occupation.value_counts()[:10]
# Out:
# RETIRED                                   233990
# INFORMATION REQUESTED                      35107
# ATTORNEY                                   34286
# HOMEMAKER                                  29931
# PHYSICIAN                                  23432
# INFORMATION REQUESTED PER BEST EFFORTS     21138
# ENGINEER                                   14334
# TEACHER                                    13990
# CONSULTANT                                 13273
# PROFESSOR                                  12555
# Name: contbr_occupation, dtype: int64

# %%
occ_mapping={'INFORMATION REQUESTED PER BEST EFFORTS':'NOT PROVIDED','INFORMATION REQUESTED':'NOT PROVIDED','INFORMATION REQUESTED (BEST EFFORTS)':'NOTPROVIDED','C.E.O.':'CEO'}

f = lambda x: occ_mapping.get(x, x)

fec.contbr_occupation = fec.contbr_occupation.map(f)

emp_mapping={'INFORMATION REQUESTED PER BEST EFFORTS':'NOT PROVIDED','INFORMATION REQUESTED':'NOT PROVIDED','SELF':'SELF EMPLOYED','SELF-EMPLOYED':'SELF-EMPLOYED',}

f2 = lambda x: emp_mapping.get(x, x)

fec.contbr_employer = fec.contbr_employer.map(f2)

by_occupation = fec.pivot_table('contb_receipt_amt', index='contbr_occupation', columns='party',aggfunc='sum')

over_2mm = by_occupation[by_occupation.sum(1) > 2000000]
over_2mm
# Out:
# /Users/lirawx/.pyenv/versions/anaconda3-5.3.0/lib/python3.6/site-packages/pandas/core/generic.py:5096: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value
# party                 Democrat    Republican
# contbr_occupation
# ATTORNEY           11141982.97  7.448183e+06
# CEO                 2074974.79  4.204201e+06
# CONSULTANT          2459912.71  2.524520e+06
# ENGINEER             951525.55  1.799217e+06
# EXECUTIVE           1355161.05  4.120100e+06
# HOMEMAKER           4248875.80  1.361398e+07
# INVESTOR             884133.00  2.422069e+06
# LAWYER              3160478.87  3.897243e+05
# MANAGER              762883.22  1.436542e+06
# NOT PROVIDED        4866973.96  2.021629e+07
# OWNER               1001567.36  2.404332e+06
# PHYSICIAN           3735124.94  3.575220e+06
# PRESIDENT           1878509.95  4.710514e+06
# PROFESSOR           2165071.08  2.940327e+05
# REAL ESTATE          528902.09  1.622357e+06
# RETIRED            25305116.38  2.334671e+07
# SELF-EMPLOYED        672393.40  1.621825e+06

# %%
over_2mm.plot(kind='barh')
#对各党派总出资额最高的职业

# %%
def get_top_amounts(group,key,n=5):
    totals = group.groupby(key)['contb_receipt_amt'].sum()
    #根据key对totals进行降序排列
    return totals.nlargest(n)

#根据职业和雇主进行聚合
grouped = fec_mrbo.groupby('cand_nm')
grouped.apply(get_top_amounts,'contbr_occupation',n=7)
grouped.apply(get_top_amounts,'contbr_employer',n=10)

#根据出资额的大小将数据离散化到多个面元中
bins = np.array([0, 1, 10, 100, 1000, 10000,
                 100000, 1000000, 10000000])
labels = pd.cut(fec_mrbo.contb_receipt_amt,bins)
#print(labels)
#根据候选人姓名以及面元标签对数据进行分组
grouped = fec_mrbo.groupby(['cand_nm',labels])
grouped.size().unstack(0)
#在小额赞助方面，obama获得的数量比romney多得多，还可以对出资额求和并在面元内规格化，以便图形化显示两位候选人的各种赞助额度的比例
bucket_sums = grouped.contb_receipt_amt.sum().unstack(0)
normed_sums = bucket_sums.div(bucket_sums.sum(axis=1), axis=0)
normed_sums[:-2].plot(kind='barh')

# %%
#根据州统计赞助信息
grouped = fec_mrbo.groupby(['cand_nm','contbr_st'])
totals = grouped.contb_receipt_amt.sum().unstack(0).fillna(0)
totals = totals[totals.sum(1) > 100000]
percent = totals.div(totals.sum(1),axis=0)
#print(percent)
percent.plot(kind='barh')
